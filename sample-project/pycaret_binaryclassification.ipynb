# %% [markdown]
# # **1. Install pycaret**

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 84.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 71.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **2. Check the pycaret version**

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.2.0

# %% [markdown]
# # **3. Get the dataset from github**

# %%
import pandas as pd
dataset_url = 'https://raw.githubusercontent.com/ExpressNesters/ExpressEats/main/sample-project/loan_approval_dataset_binary_classification.csv'
dataset = pd.read_csv(dataset_url)

# %% [markdown]
# # **4. Scan the dataset**

# %%
print("(Rows, Columns) in the dataset : ", dataset.shape, "\n\n")
dataset.head()
# Out:
# (Rows, Columns) in the dataset :  (4269, 13)
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
# ...

# %% [markdown]
# # **5. Divide the data**

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index).reset_index(drop=True)
data = data.reset_index(drop=True)

print("Data for modeling : ", data.shape)
print("Unseen data for predictions : ", data_unseen.shape)
# Out:
# Data for modeling :  (4056, 13)
# Unseen data for predictions :  (213, 13)

# %%
data.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0     1499                  1   Not Graduate             No        2900000
# 1     2450                  5       Graduate            Yes        5200000
# 2     2017                  4   Not Graduate             No        5800000
# 3     2444                  4   Not Graduate            Yes        6700000
# 4     2961                  1   Not Graduate            Yes        1000000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0       7400000          10           874                     400000
# 1      12700000          16           718                   11700000
# 2      14200000          20           535                   10200000
# 3      24700000           6           498                   12900000
# 4       2100000           8           793                    2900000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
data_unseen.head()
# Out:
#    loan_id   no_of_dependents  education  self_employed   income_annum  \
# 0        6                  0   Graduate            Yes        4800000
# 1       14                  2   Graduate            Yes        9100000
# 2       19                  2   Graduate             No        2700000
# 3       32                  2   Graduate             No        5700000
# 4       58                  5   Graduate            Yes        9300000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      13500000          10           319                    6800000
# 1      31500000          14           679                   10800000
# 2      10300000          10           736                    1000000
# 3      12000000           6           363                    3600000
# 4      30500000          18           841                   19300000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %% [markdown]
# # **6. Setup pycaret**

# %%
from pycaret.classification import *

exp_loan_data = setup(data = data, target = ' loan_status', session_id=333, use_gpu=True)
# Out:
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 2, number of used features: 0
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Warning] Using sparse features with CUDA is currently not supported.
# [LightGBM] [Info] Number of positive: 1, number of negative: 1
# ...

# %% [markdown]
# #**7. Compare all the Models**

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_c547d th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # **8. Create a Model**
# Choosing **Extreme Gradient Boosting** model - xgboost

# %%
xgboost = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_0507d_row10_col0, #T_0507d_row10_col1, #T_0507d_row10_col2, #T_0507d_row10_col3, #T_0507d_row10_col4, #T_0507d_row10_col5, #T_0507d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0507d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0507d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0507d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0507d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0507d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0507d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0507d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0507d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
print(xgboost)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='gpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=-1,
#               num_parallel_tree=None, objective='binary:logistic', ...)

# %% [markdown]
# # **9. Tune a model**

# %%
tuned_xgboost = tune_model(xgboost)
# Out:
# <style type="text/css">
# #T_012bc_row10_col0, #T_012bc_row10_col1, #T_012bc_row10_col2, #T_012bc_row10_col3, #T_012bc_row10_col4, #T_012bc_row10_col5, #T_012bc_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_012bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_012bc_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_012bc_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_012bc_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_012bc_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_012bc_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_012bc_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_012bc_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# # **10. Plot Model**

# %%
plot_model(tuned_xgboost, plot = 'auc')

# %%
plot_model(tuned_xgboost, plot = 'pr')

# %%
plot_model(tuned_xgboost, plot = 'confusion_matrix')

# %%
plot_model(tuned_xgboost, plot = 'feature')

# %%
evaluate_model(tuned_xgboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # **11. Predict Model**

# %%
predict_model(tuned_xgboost)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a59b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a59b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8a59b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8a59b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8a59b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8a59b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8a59b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8a59b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8a59b_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a59b_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# # **12. Finalize Model**

# %%
final_xgboost = finalize_model(tuned_xgboost)

print(final_xgboost)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['loan_id', ' no_of_dependents',
#                                              ' income_annum', ' loan_amount',
#                                              ' loan_term', ' cibil_score',
#                                              ' residential_assets_value',
#                                              ' commercial_assets_value',
#                                              ' lu...
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
# ...

# %%
predict_model(final_xgboost)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3dfa0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dfa0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3dfa0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3dfa0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3dfa0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3dfa0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3dfa0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3dfa0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3dfa0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dfa0_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# # **13. Predict on Unseen data**

# %%
unseen_predictions = predict_model(final_xgboost, data=data_unseen)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_331f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_331f9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_331f9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_331f9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_331f9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_331f9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_331f9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_331f9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_331f9_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_331f9_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# # **14. Saving the model**

# %%
save_model(final_xgboost,'Final XGBOOST Model Version 1')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['loan_id', ' no_of_dependents',
#                                               ' income_annum', ' loan_amount',
#                                               ' loan_term', ' cibil_score',
#                                               ' residential_assets_value',
#                                               ' commercial_assets_value',
#                                               ' lu...
#                                 importance_type=None,
#                                 interaction_constraints=None, learning_rate=None,
# ...

# %% [markdown]
# # **15. Load the saved model (for future use)**

# %%
saved_final_xgboost = load_model('Final XGBOOST Model Version 1')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
new_prediction = predict_model(saved_final_xgboost, data=data_unseen)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9e12" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9e12_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d9e12_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d9e12_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d9e12_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d9e12_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d9e12_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d9e12_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d9e12_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9e12_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
new_prediction.head(50)
# Out:
#     loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0         6                  0       Graduate            Yes        4800000
# 1        14                  2       Graduate            Yes        9100000
# 2        19                  2       Graduate             No        2700000
# 3        32                  2       Graduate             No        5700000
# 4        58                  5       Graduate            Yes        9300000
# 5        72                  5       Graduate            Yes        5300000
# 6        84                  3       Graduate             No        3600000
# 7        87                  5   Not Graduate            Yes        1100000
# 8        98                  2   Not Graduate             No        8700000
# 9       104                  4       Graduate             No        1600000
# 10      117                  4   Not Graduate            Yes        5800000
# ...

# %%
import pickle

# Saving model to disk
pickle.dump(saved_final_xgboost, open('saved_final_xgboost.pkl','wb'))
